# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirHoseein99/Custom_yolo/blob/master/Custom_yolo_object_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# cloning alexeyAb darknet

# %%
# !git clone "https://github.com/AlexeyAB/darknet" "/content/drive/MyDrive/Custom_Object_Detection/darknet"

# %% [markdown]
# change dir to make darknet

# %%
# %cd "/content/drive/MyDrive/Custom_Object_Detection/darknet"
! make
# Out:
# /content/drive/MyDrive/Custom_Object_Detection/darknet

# %% [markdown]
# extracting custom dataset

# %%
! unzip "/content/drive/MyDrive/Custom_Object_Detection/custom_dataset.zip" -d "/content/drive/MyDrive/Custom_Object_Detection"

# %% [markdown]
# creating our train, test files and .data file

# %%
# %cd "/content/drive/MyDrive/Custom_Object_Detection"
! python "/content/drive/MyDrive/Custom_Object_Detection/custom_dataset/creating-files-data-and-name.py"
! python "/content/drive/MyDrive/Custom_Object_Detection/custom_dataset/creating-train-and-test-txt-files.py"
# Out:
# /content/drive/MyDrive/Custom_Object_Detection

# %% [markdown]
# getting the custom weights for trainning, we are not training from scratch becaues our datset is very small

# %%
# !wget "https://pjreddie.com/media/files/darknet53.conv.74" -O "/content/drive/MyDrive/Custom_Object_Detection/custom_weight/darknet53.conv.74"

# %% [markdown]
# training the yolov3 with free gpu from colab

# %%
! ./darknet/darknet detector train /content/drive/MyDrive/Custom_Object_Detection/custom_dataset/labelled_data.data /content/drive/MyDrive/Custom_Object_Detection/darknet/cfg/yolov3_custom.cfg   -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 102346, rewritten_bbox = 0.022473 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.883469), count: 2, class_loss = 0.566681, iou_loss = 0.248355, total_loss = 0.815036
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 102348, rewritten_bbox = 0.022472 %
#
#  Tensor Cores are used.
#
#  3867: 0.511175, 0.421113 avg loss, 0.001000 rate, 1.302119 seconds, 30936 images, 0.114023 hours left
# Loaded: 0.000043 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.870337), count: 1, class_loss = 0.003673, iou_loss = 0.082413, total_loss = 0.086085
# ...
